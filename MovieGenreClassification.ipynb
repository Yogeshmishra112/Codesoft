# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
train_data = pd.read_csv("train_data.csv",sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
display(train_data.head())
print(train_data.shape)
# Out:
# <ipython-input-26-9de63bee14a5>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   train_data = pd.read_csv("train_data.csv",sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
#     ID                               TITLE       GENRE  \
# 0  "1        Oscar et la dame rose (2009)       drama
# 1  "2                        Cupid (1997)    thriller
# 2  "3    Young, Wild and Wonderful (1980)       adult
# 3  "4               The Secret Sin (1915)       drama
# 4  "5              The Unrecovered (2007)       drama
#
#                                          DESCRIPTION
# 0   Listening in to a conversation between his do...
# 1   A brother and sister with a past incestuous r...
# 2   As the bus empties the students for their fie...
# 3   To help their unemployed father make ends mee...
# ...

# %%
test_data = pd.read_csv("test_data.csv",sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
print(display(test_data.head()))
print(test_data.shape)
# Out:
# <ipython-input-27-59bb7c1631fb>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   test_data = pd.read_csv("test_data.csv",sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
#     ID                          TITLE  \
# 0  "1           Edgar's Lunch (1998)
# 1  "2       La guerra de papá (1977)
# 2  "3    Off the Beaten Track (2010)
# 3  "4         Meu Amigo Hindu (2015)
# 4  "5              Er nu zhai (1955)
#
#                                                GENRE  DESCRIPTION
# 0   L.R. Brane loves his life - his car, his apar...          NaN
# 1   Spain, March 1964: Quico is a very naughty ch...          NaN
# 2   One year in the life of Albin and his family ...          NaN
# 3   His father has died, he hasn't spoken with hi...          NaN
# ...

# %%
test_solution_data = pd.read_csv("test_data_solution.csv",sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
print(display(test_solution_data.head()))
print(test_solution_data.shape)
# Out:
# <ipython-input-28-21a870a3a3c8>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   test_solution_data = pd.read_csv("test_data_solution.csv",sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
#     ID                          TITLE          GENRE  \
# 0  "1           Edgar's Lunch (1998)       thriller
# 1  "2       La guerra de papá (1977)         comedy
# 2  "3    Off the Beaten Track (2010)    documentary
# 3  "4         Meu Amigo Hindu (2015)          drama
# 4  "5              Er nu zhai (1955)          drama
#
#                                          DESCRIPTION
# 0   L.R. Brane loves his life - his car, his apar...
# 1   Spain, March 1964: Quico is a very naughty ch...
# 2   One year in the life of Albin and his family ...
# ...

# %%
plt.figure(figsize=(20,8))
sns.countplot(y=train_data['GENRE'], order = train_data['GENRE'].value_counts().index)
plt.title('Number of Movies per Genre')
plt.xlabel('Number of Movies')
plt.ylabel('Genre')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset with the correct delimiter
file_path = '/content/train_data.csv'
train_data = pd.read_csv(file_path, delimiter=':::', engine='python', header=None)

# Assign column names (based on the data observed)
train_data.columns = ['Index', 'Title', 'Genre', 'Description']

# Count the number of movies per genre
genre_counts = train_data['Genre'].value_counts()

# Plot the vertical histogram
plt.figure(figsize=(12, 8))
sns.countplot(x=train_data['Genre'], order=train_data['Genre'].value_counts().index, palette='Set2')
plt.title('Number of Movies per Genre (Vertical)')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.xticks(rotation=90)  # Rotate x labels for better readability
plt.show()
# Out:
# <ipython-input-49-9986880d19ad>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=train_data['Genre'], order=train_data['Genre'].value_counts().index, palette='Set2')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset with the correct delimiter
file_path = '/content/train_data.csv'
train_data = pd.read_csv(file_path, delimiter=':::', engine='python', header=None)

# Assign column names (based on the data observed)
# Make sure the column name for description matches what you use later
train_data.columns = ['Index', 'Title', 'Genre', 'Description']

# Calculate description length
train_data['DESCRIPTION_length'] = train_data['Description'].apply(len) # Use 'Description' here

plt.figure(figsize=(15, 10))
sns.barplot(x='Genre', y='DESCRIPTION_length', data=train_data) # And 'Genre' here to match the column name
plt.title('Description Length by Genre')
plt.xticks(rotation=45)
plt.xlabel('Genre')
plt.ylabel('Description Length')
plt.show()

# %%
# Handle any potential missing values
# Handle any potential missing values

train_data['Description'].fillna("", inplace=True) # Changed 'DESCRIPTION' to 'Description'
test_data['DESCRIPTION'].fillna("", inplace=True)  # Changed 'DESCRIPTION' to 'Description'

# ... rest of your code

t_v = TfidfVectorizer(stop_words='english', max_features=100000)
X_train = t_v.fit_transform(train_data['Description'])
X_test = t_v.transform(test_data['DESCRIPTION'])

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_data['Genre'])
y_test = label_encoder.transform(test_solution_data['GENRE'])

# %%
X_train_sub, X_val, y_train_sub, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

clf = LinearSVC()
clf.fit(X_train_sub, y_train_sub)

y_val_pred = clf.predict(X_val)
print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))
print("Validation Classification Report:\n", classification_report(y_val, y_val_pred))
# Out:
# Validation Accuracy: 0.5836945494789265
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.44      0.32      0.37       263
#            1       0.74      0.44      0.55       112
#            2       0.45      0.21      0.28       139
#            3       0.47      0.15      0.23       104
#            4       0.00      0.00      0.00        61
#            5       0.53      0.59      0.56      1443
#            6       0.39      0.07      0.11       107
#            7       0.69      0.81      0.75      2659
#            8       0.56      0.72      0.63      2697
#            9       0.36      0.17      0.23       150
#           10       0.13      0.03      0.04        74
#           11       0.82      0.68      0.74        40
#           12       0.00      0.00      0.00        45
#           13       0.65      0.66      0.66       431
#           14       0.61      0.53      0.57       144
# ...

# %%
# Assuming 'test_data' is already loaded and preprocessed similarly to 'train_data'

# ... rest of your code

# Double-check the shapes of your data before prediction
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)

y_pred = clf.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("Test Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Shape of X_test: (54200, 100000)
# Shape of y_test: (54200,)
# Test Accuracy: 0.09357933579335793
# Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1314
#            1       0.00      0.00      0.00       590
#            2       0.00      0.00      0.00       775
#            3       0.00      0.00      0.00       498
#            4       0.00      0.00      0.00       264
#            5       0.00      0.00      0.00      7446
#            6       0.00      0.00      0.00       505
#            7       0.00      0.00      0.00     13096
#            8       0.00      0.00      0.00     13612
#            9       0.00      0.00      0.00       783
#           10       0.00      0.00      0.00       322
#           11       0.00      0.00      0.00       193
#           12       0.00      0.00      0.00       243
#           13       0.00      0.00      0.00      2204
# ...

# %%
from sklearn.naive_bayes import MultinomialNB
Mnb_classifier = MultinomialNB()
Mnb_classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
Mnb_classifier.predict(X_test)
# Out:
# array([8, 8, 8, ..., 8, 8, 8])

# %%
from sklearn.linear_model import LogisticRegression
lr_classifier = LogisticRegression(max_iter=500)
lr_classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
lr_classifier.predict(X_test)
# Out:
# array([8, 8, 8, ..., 8, 8, 8])

# %%
def predict_movie(description):
    t_v1 = t_v.transform([description])
    pred_label = clf.predict(t_v1)
    return label_encoder.inverse_transform(pred_label)[0]

sample_descr_for_movie = "A movie where a gang is active and murdering"
print(predict_movie(sample_descr_for_movie))

sample_descr_for_movie1 = "A movie where person cashes a girl too get marry with him but girl refuses him."
print(predict_movie(sample_descr_for_movie1))
# Out:
#  thriller
#  drama

# %%
import pickle

# %%
pickle.dump(clf,open('moviegenreclassification.pkl','wb'))
